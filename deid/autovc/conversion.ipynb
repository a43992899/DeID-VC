# %% [markdown]
# # convert autovc output mel spec to wav

# %%
import os
import pickle
import torch
import numpy as np
from math import ceil
from model_vc import Generator
from model_vae import VAE
from tqdm import tqdm
from hparams import DATA_PATH
import random

EVAL_SCHEME_LIST = ['TRAINxTRAIN', 'TRAINxTEST', 'TESTxTEST', 'TESTxTRAIN', 'TRAINxVOX', 'TESTxVOX', 'TRAINxPSEUDO', 'TESTxPSEUDO']
EVAL_SCHEME = EVAL_SCHEME_LIST[-1]
EVAL_MODEL_LIST = ['default', 'enhanced_content', 'enhanced_content_emb', 'enhanced_content_emb_l1_vae', 'enhanced_content_l1_vae', 'test']
EVAL_MODEL = EVAL_MODEL_LIST[-3]

# # default model
if EVAL_MODEL == 'default':
    model_path = "/home/yrb/code/ID-DEID/data/model/freq32/autovc_epoch_95_loss_0.0026.ckpt"
    output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/default/'

# content_loss
if EVAL_MODEL == 'enhanced_content':
    model_path = "/home/yrb/code/ID-DEID/data/model/enhanced_freq32/autovc_epoch_98_loss_0.0350.ckpt"
    output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/enhanced_content/'

# content+emb_loss
if EVAL_MODEL == 'enhanced_content_emb':
    model_path = "/home/yrb/code/ID-DEID/data/model/enhanced_freq32+emb_loss/autovc_epoch_97_loss_0.0058.ckpt"
    output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/enhanced_content_emb/'

# # content_loss + mse_vae
# if EVAL_MODEL == 'enhanced_content_mse_vae':
#     model_path = "/home/yrb/code/ID-DEID/data/model/enhanced_freq32/autovc_epoch_98_loss_0.0350.ckpt"
#     output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/enhanced_content_mse_vae/'
#     vae_path = "/home/yrb/code/ID-DEID/data/vae_model/vae_wo_cos_on_voxceleb.ckpt"

# content_loss + l1_vae
if EVAL_MODEL == 'enhanced_content_l1_vae':
    model_path = "/home/yrb/code/ID-DEID/data/model/enhanced_freq32/autovc_epoch_98_loss_0.0350.ckpt"
    output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/enhanced_content_l1_vae/'
    vae_path = "/home/yrb/code/ID-DEID/data/vae_model/l1_vae_on_voxceleb_finetune_on_wsj.ckpt"

# content+emb_loss + l1_vae
if EVAL_MODEL == 'enhanced_content_emb_l1_vae':
    model_path = "/home/yrb/code/ID-DEID/data/model/enhanced_freq32+emb_loss/autovc_epoch_97_loss_0.0058.ckpt"
    output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/enhanced_content_emb_l1_vae/'
    vae_path = "/home/yrb/code/ID-DEID/data/vae_model/l1_vae_on_voxceleb_finetune_on_wsj.ckpt"

# content_loss
if EVAL_MODEL == 'test':
    model_path = "/home/yrb/code/ID-DEID/data/model/autovc_best.ckpt"
    output_path = f'/home/yrb/data/ID-DEID_data/autovc_poster_infer/{EVAL_SCHEME}/full/test/'

torch.set_num_threads(4)
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

G = Generator(32,256,512,32).eval().to(device)
g_checkpoint = torch.load(model_path, map_location=device)
G.load_state_dict(g_checkpoint['model'])
print('epoch', int((g_checkpoint['iter']+1)/5000))

if 'PSEUDO' in EVAL_SCHEME:
    Vae = VAE(256, 384, 64, device).to(device)
    Vae_checkpoint = torch.load(vae_path, map_location=device)
    Vae.load_state_dict(Vae_checkpoint['model'])

metadata_wsj = pickle.load(open(DATA_PATH+'wsj_spmel/train.pkl', "rb"))
metadata_vctk = pickle.load(open(DATA_PATH+'vctk_spmel/train.pkl', "rb"))
metadata_vox = pickle.load(open(DATA_PATH+'voxceleb_spmel/train.pkl', "rb"))

# only run portion of meta
metadata = []
src_utter_id_list = []
src_list = []
trg_list = []
if EVAL_SCHEME == 'TRAINxTRAIN':
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i])
        src_list.append(metadata_wsj[sbmt_i][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i]))]))
        
        metadata.append(metadata_wsj[sbmt_i+100])
        trg_list.append(metadata_wsj[sbmt_i+100][0])
        src_utter_id_list.append(None) # trgs don't need utters
elif EVAL_SCHEME == 'TRAINxTEST':
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i])
        src_list.append(metadata_wsj[sbmt_i][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i]))]))
        
        metadata.append(metadata_wsj[sbmt_i+300])
        trg_list.append(metadata_wsj[sbmt_i+300][0])
        src_utter_id_list.append(None)
elif EVAL_SCHEME == 'TESTxTEST':
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i+300])
        src_list.append(metadata_wsj[sbmt_i+300][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i+300]))]))
        
        metadata.append(metadata_wsj[sbmt_i+301])
        trg_list.append(metadata_wsj[sbmt_i+301][0])
        src_utter_id_list.append(None) # trgs don't need utters
elif EVAL_SCHEME == 'TESTxTRAIN':
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i+300])
        src_list.append(metadata_wsj[sbmt_i+300][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i+300]))]))

        metadata.append(metadata_wsj[sbmt_i])
        trg_list.append(metadata_wsj[sbmt_i][0])
        src_utter_id_list.append(None)
elif EVAL_SCHEME == 'TRAINxVOX':
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i])
        src_list.append(metadata_wsj[sbmt_i][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i]))]))
        
        metadata.append(metadata_vox[sbmt_i])
        trg_list.append(metadata_vox[sbmt_i][0])
        src_utter_id_list.append(None) # trgs don't need utters
elif EVAL_SCHEME == 'TRAINxPSEUDO':
    noise = torch.randn(100, 64).to(device)
    generated_emb = Vae.Decoder(noise)
    generated_emb = generated_emb.cpu().detach().numpy()
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i])
        src_list.append(metadata_wsj[sbmt_i][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i]))]))
        
        fake_meta = [f'pseudo_{sbmt_i}', generated_emb[sbmt_i], None]
        metadata.append(fake_meta)
        trg_list.append(fake_meta[0])
        src_utter_id_list.append(None) # trgs don't need utters
elif EVAL_SCHEME == 'TESTxPSEUDO':
    noise = torch.randn(100, 64).to(device)
    generated_emb = Vae.Decoder(noise)
    generated_emb = generated_emb.cpu().detach().numpy()
    for sbmt_i in range(100):
        metadata.append(metadata_wsj[sbmt_i+300])
        src_list.append(metadata_wsj[sbmt_i+300][0])
        src_utter_id_list.append(random.choice([i for i in range(3, len(metadata_wsj[sbmt_i+300]))]))
        
        fake_meta = [f'pseudo_{sbmt_i}', generated_emb[sbmt_i], None]
        metadata.append(fake_meta)
        trg_list.append(fake_meta[0])
        src_utter_id_list.append(None) # trgs don't need utters
else:
    raise NotImplementedError
# Out:
# epoch 97

# %%
def pad_seq(x, base=32):
    len_out = int(base * ceil(float(x.shape[0])/base))
    len_pad = len_out - x.shape[0]
    assert len_pad >= 0
    return np.pad(x, ((0,len_pad),(0,0)), 'constant'), len_pad

def determine_dataset(spkrid):
    if spkrid == 's5' or (len(spkrid) == 4 and spkrid.startswith('p')):
        return 'vctk'
    elif len(spkrid) == 3:
        return 'wsj'
    elif len(spkrid) == 7 and spkrid.startswith('id'):
        return 'vox'
    else:
        raise NotImplementedError(f'invalid spkrid: {spkrid}')

def get_wavs_and_spmel_dir(spkrid):
    dataset_name = determine_dataset(spkrid)
    if dataset_name == 'wsj':
        return os.path.join(DATA_PATH, 'wsj_wavs'), os.path.join(DATA_PATH, 'wsj_spmel')
    elif dataset_name == 'vctk':
        return os.path.join(DATA_PATH, 'vctk_wavs'), os.path.join(DATA_PATH, 'vctk_spmel')
    elif dataset_name == 'vox':
        return os.path.join(DATA_PATH, 'voxceleb_wavs'), os.path.join(DATA_PATH, 'voxceleb_spmel')
    else:
        raise NotImplementedError(f'invalid dataset_name: {dataset_name}')

src_utter_id_list_path = os.path.join(output_path, '../utter_id_list.pkl')
os.makedirs(os.path.dirname(src_utter_id_list_path), exist_ok=True)
if os.path.exists(src_utter_id_list_path):
    with open(src_utter_id_list_path, 'rb') as ff:
        src_utter_id_list = pickle.load(ff)
else:
    with open(src_utter_id_list_path, 'wb') as ff:
        pickle.dump(src_utter_id_list, ff)

spect_vc = []
cropping = True

for sbmt_i_idx, sbmt_i in enumerate(tqdm(metadata)):
    if sbmt_i[0] not in src_list: continue
    if src_utter_id_list[sbmt_i_idx] == None: continue

    # get original utterance name, wavs dir and spmel dir
    wavs_dir, spmel_dir = get_wavs_and_spmel_dir(sbmt_i[0])
    x_org = sbmt_i[src_utter_id_list[sbmt_i_idx]]

    # copy original wav
    src_wav_path = os.path.join(wavs_dir, x_org.replace('.npy', '.wav'))
    cp_wav_path = os.path.join(output_path, 'src')
    os.makedirs(cp_wav_path, exist_ok=True)
    os.system(f"cp {src_wav_path} {cp_wav_path}")

    # get original utterance spmel and embedding
    x_org = np.load(os.path.join(spmel_dir, x_org))
    x_org, len_pad = pad_seq(x_org, base=128)
    start = 0 if cropping else 0
    uttr_org = torch.from_numpy(x_org[np.newaxis, start:, :]).to(device)
    uttr_org = uttr_org.reshape(-1, 128, 80) if cropping else uttr_org
    emb_org = torch.from_numpy(sbmt_i[1][np.newaxis, :]).repeat(uttr_org.shape[0],1).to(device)
    
    for sbmt_j_idx, sbmt_j in enumerate(metadata):
        if sbmt_j[0] not in trg_list: continue
        if src_list.index(sbmt_i[0]) != trg_list.index(sbmt_j[0]): continue

        # copy target wav
        if 'pseudo' not in sbmt_j[0]:
            wavs_dir, spmel_dir = get_wavs_and_spmel_dir(sbmt_j[0])
            trg_utter = sbmt_j[2]
            trg_wav_path = os.path.join(wavs_dir, trg_utter.replace('.npy', '.wav'))
            cp_wav_path = os.path.join(output_path, 'trg')
            os.makedirs(cp_wav_path, exist_ok=True)
            new_trg_wav_name = trg_utter.replace('.npy', '.wav').replace('/', '_')
            os.system(f"cp {trg_wav_path} {cp_wav_path}/{new_trg_wav_name}")
            
        emb_trg = torch.from_numpy(sbmt_j[1][np.newaxis, :]).repeat(uttr_org.shape[0],1).to(device)
        
        with torch.no_grad():
            _, x_identic_psnt, _ = G(uttr_org, emb_org, emb_trg) # TODO: emb_trg
        x_identic_psnt = x_identic_psnt.reshape(1, 1, -1, 80)
            
        if len_pad == 0:
            uttr_trg = x_identic_psnt[0, 0, :, :].cpu().numpy()
        else:
            uttr_trg = x_identic_psnt[0, 0, :-len_pad, :].cpu().numpy()
        
        spect_vc.append( ('{}x{}'.format(sbmt_i[0], sbmt_j[0]), uttr_trg) )
    with open(os.path.join(output_path, 'results.pkl'), 'wb') as handle:
        pickle.dump(spect_vc, handle)
# Out:
# 100%|██████████| 200/200 [00:09<00:00, 20.50it/s]

# %% [markdown]
# # Hifi-GAN infer

# %%
import os
from hparams import DATA_PATH
command = "python /home/yx/hifi-gan/inference_e2e.py "
# Add pickle path here
command += "--input_pkl_dir "
command += os.path.join(output_path, 'results.pkl') + " "
# Add output path here
command += "--output_wavs_dir "
command += output_path
print(command)
os.system(command)
# Out:
# python /home/yx/hifi-gan/inference_e2e.py --input_pkl_dir /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/results.pkl --output_wavs_dir /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/
# Initializing Inference Process..
# Loading '/home/yx/hifi-gan/pretrained/VCTK_V1/g_03280000'
# Complete.
# Removing weight norm...
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49gxpseudo_0.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49hxpseudo_1.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49ixpseudo_2.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49jxpseudo_3.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49kxpseudo_4.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49lxpseudo_5.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49mxpseudo_6.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49nxpseudo_7.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49oxpseudo_8.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49pxpseudo_9.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49qxpseudo_10.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49rxpseudo_11.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49sxpseudo_12.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49txpseudo_13.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49uxpseudo_14.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49vxpseudo_15.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49wxpseudo_16.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49xxpseudo_17.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49yxpseudo_18.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/49zxpseudo_19.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a0xpseudo_20.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a1xpseudo_21.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a2xpseudo_22.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a3xpseudo_23.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a4xpseudo_24.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a5xpseudo_25.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a6xpseudo_26.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a7xpseudo_27.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a8xpseudo_28.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4a9xpseudo_29.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4aaxpseudo_30.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4abxpseudo_31.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4acxpseudo_32.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4adxpseudo_33.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4aexpseudo_34.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4afxpseudo_35.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4agxpseudo_36.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4ahxpseudo_37.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4aixpseudo_38.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4ajxpseudo_39.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4akxpseudo_40.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4alxpseudo_41.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4amxpseudo_42.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4anxpseudo_43.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4aoxpseudo_44.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4apxpseudo_45.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4aqxpseudo_46.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4arxpseudo_47.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4asxpseudo_48.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4atxpseudo_49.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4auxpseudo_50.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4avxpseudo_51.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4awxpseudo_52.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4axxpseudo_53.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4ayxpseudo_54.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4azxpseudo_55.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b0xpseudo_56.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b1xpseudo_57.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b2xpseudo_58.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b3xpseudo_59.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b4xpseudo_60.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b5xpseudo_61.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b6xpseudo_62.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b7xpseudo_63.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b8xpseudo_64.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4b9xpseudo_65.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4baxpseudo_66.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bbxpseudo_67.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bcxpseudo_68.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bdxpseudo_69.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bexpseudo_70.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bfxpseudo_71.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bgxpseudo_72.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bhxpseudo_73.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bixpseudo_74.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4bjxpseudo_75.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k0xpseudo_76.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k1xpseudo_77.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k2xpseudo_78.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k3xpseudo_79.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k4xpseudo_80.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k6xpseudo_81.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k7xpseudo_82.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k8xpseudo_83.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4k9xpseudo_84.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4kaxpseudo_85.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l0xpseudo_86.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l1xpseudo_87.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l2xpseudo_88.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l3xpseudo_89.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l4xpseudo_90.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l5xpseudo_91.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l6xpseudo_92.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l7xpseudo_93.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l8xpseudo_94.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4l9xpseudo_95.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4laxpseudo_96.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4lbxpseudo_97.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4lcxpseudo_98.wav
# /home/yrb/data/ID-DEID_data/autovc_poster_infer/TESTxPSEUDO/full/enhanced_content_emb_l1_vae/4ldxpseudo_99.wav
# 0
